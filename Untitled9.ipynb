# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=pd.read_csv(r'/content/drive/MyDrive/data science/titanic.csv')
titanic
# Out:
#      Unnamed: 0  PassengerId  \
# 0             0            1
# 1             1            2
# 2             2            3
# 3             3            4
# 4             4            5
# ..          ...          ...
# 886         886          887
# 887         887          888
# 888         888          889
# 889         889          890
# 890         890          891
#
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 4                             Allen, Mr. William Henry       3    male  35.0
# ..                                                 ...     ...     ...   ...
# ...

# %%
titanic.head()
# Out:
#    Unnamed: 0  PassengerId                                               Name  \
# 0           0            1                            Braund, Mr. Owen Harris
# 1           1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           2            3                             Heikkinen, Miss. Laina
# 3           3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           4            5                           Allen, Mr. William Henry
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked  Survived
# 0        S         0
# 1        C         1
# ...

# %%
titanic.tail()
# Out:
#      Unnamed: 0  PassengerId                                      Name  \
# 886         886          887                     Montvila, Rev. Juozas
# 887         887          888              Graham, Miss. Margaret Edith
# 888         888          889  Johnston, Miss. Catherine Helen "Carrie"
# 889         889          890                     Behr, Mr. Karl Howell
# 890         890          891                       Dooley, Mr. Patrick
#
#      Pclass     Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886       2    male  27.0      0      0      211536  13.00   NaN        S
# 887       1  female  19.0      0      0      112053  30.00   B42        S
# 888       3  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889       1    male  26.0      0      0      111369  30.00  C148        C
# 890       3    male  32.0      0      0      370376   7.75   NaN        Q
#
#      Survived
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0

# %%
titanic.describe()
# Out:
#        Unnamed: 0  PassengerId      Pclass         Age       SibSp  \
# count  891.000000   891.000000  891.000000  714.000000  891.000000
# mean   445.000000   446.000000    2.308642   29.699118    0.523008
# std    257.353842   257.353842    0.836071   14.526497    1.102743
# min      0.000000     1.000000    1.000000    0.420000    0.000000
# 25%    222.500000   223.500000    2.000000   20.125000    0.000000
# 50%    445.000000   446.000000    3.000000   28.000000    0.000000
# 75%    667.500000   668.500000    3.000000   38.000000    1.000000
# max    890.000000   891.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    Survived
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.383838
# std      0.806057   49.693429    0.486592
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    0.000000
# 75%      0.000000   31.000000    1.000000
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Name         891 non-null    object
#  3   Pclass       891 non-null    int64
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Survived     891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
print(titanic.isnull().sum())
# Out:
# Unnamed: 0       0
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
titanic.dropna(axis=0,inplace=True)
titanic
# Out:
#      Unnamed: 0  PassengerId  \
# 1             1            2
# 3             3            4
# 6             6            7
# 10           10           11
# 11           11           12
# ..          ...          ...
# 871         871          872
# 872         872          873
# 879         879          880
# 887         887          888
# 889         889          890
#
#                                                   Name  Pclass     Sex   Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 6                              McCarthy, Mr. Timothy J       1    male  54.0
# 10                     Sandstrom, Miss. Marguerite Rut       3  female   4.0
# 11                            Bonnell, Miss. Elizabeth       1  female  58.0
# ..                                                 ...     ...     ...   ...
# ...

# %%
titanic.to_csv('cleaned.csv')

# %%
newdf=pd.read_csv('cleaned.csv')
newdf
# Out:
#      Unnamed: 0.1  Unnamed: 0  PassengerId  \
# 0               1           1            2
# 1               3           3            4
# 2               6           6            7
# 3              10          10           11
# 4              11          11           12
# ..            ...         ...          ...
# 178           871         871          872
# 179           872         872          873
# 180           879         879          880
# 181           887         887          888
# 182           889         889          890
#
#                                                   Name  Pclass     Sex   Age  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 2                              McCarthy, Mr. Timothy J       1    male  54.0
# 3                      Sandstrom, Miss. Marguerite Rut       3  female   4.0
# ...

# %%
newdf.plot.bar()
plt.show()

# %%
newdf.plot.hist()
plt.show()

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x ="sex", hue ="survived",
kind ="count", data = titanic)

# %%
titanic.hist(color='g',figsize=(10,10),bins=30) #change color or size of graph
plt.show()

# %%
plt.figure(figsize=(4,5))
ax=sns.boxplot(data=titanic)
plt.yticks(range(5,90,10))

plt.show()

# %%
titanic.plot(kind='box',figsize=(8,5),color='r',yticks=range(0,90,10))
plt.show()

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
scatter_matrix(titanic_numeric,figsize=(10,8),color='r',diagonal='kde')
plt.show()

# %%
sns.relplot(data=titanic)
plt.show()

# %%
sns.lineplot(data=titanic)
plt.show()

# %%
titanic['Fare_Range'] = pd.qcut(titanic['Fare'], 4)
sns.barplot(x ='Fare_Range', y ='Survived',
data = titanic)
# Out:
# <Axes: xlabel='Fare_Range', ylabel='Survived'>

# %%
sns.catplot(x ='Embarked', hue ='Survived',
kind ='count', col ='Pclass', data = titanic)

# %%
import warnings
warnings.filterwarnings('ignore')
from numpy.random import randn

# %%
x=randn(100)
x
# Out:
# array([ 0.28379958,  0.5203928 , -0.40303994, -0.24109451,  0.39368832,
#         1.30129807,  0.63126522, -0.64772814,  0.94635451,  1.70274989,
#        -3.25567839, -0.66799731,  1.76031025, -0.29147252,  0.42718177,
#         1.07638658,  0.1989452 ,  1.19627945, -1.35190935, -0.22019954,
#         1.30860427,  0.99228487,  0.30932639, -0.1916935 ,  0.05098295,
#         0.89367137, -0.93668068,  0.78621409,  0.67687241,  1.34427673,
#         0.1324614 , -0.14800567,  1.14532821,  0.98868254,  0.81479935,
#        -1.3861287 ,  0.75294017,  0.94519129, -0.76857607, -0.57445747,
#         0.01316281,  0.92649571,  0.00375527,  1.43741626,  1.68624577,
#         0.19063693, -0.55970771, -0.7111354 ,  2.52219456,  1.10480471,
#         2.44326809, -0.07014236, -0.96630346,  1.66560455, -1.17959947,
#         0.16166136,  0.14634388,  0.47245431, -2.43605163, -0.05105846,
#         1.38480898, -0.12222181, -0.18454185, -1.37737939,  1.04455025,
# ...

# %%
sns.distplot(titanic['age'], kde=True, hist=False)
plt.show()

# %%
sns.distplot(titanic['age'], kde=True, hist=True)
plt.show()
